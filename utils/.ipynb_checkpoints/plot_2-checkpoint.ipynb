# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fedmach_prec_list=np.load('../save/fedmach_Eurlex_500_4.npy')
fedavg_prec_list=np.load('../save/fedavg_Eurlex.npy')
plt.figure()
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,0], 'r-', label='FedHash: Precision@1')
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,1], 'y-', label='FedHash: Precision@3')
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,2], 'b-', label='FedHash: Precision@5')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,0], 'r--', label='FedAvg: Precision@1')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,1], 'y--', label='FedAvg: Precision@3')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,2], 'b--', label='FedAvg: Precision@5')
plt.title('Non-iid Data Partition')
plt.legend()
plt.ylabel('Precision')
plt.savefig('../save/fedmach_vs_fedavg_epc_100_B500_R4_test_acc_noniid.png')

# %%
np.max(fedmach_prec_list[:,0]), np.max(fedmach_prec_list[:,1]), np.max(fedmach_prec_list[:,2])
# Out:
# (0.7657575757575757, 0.6269191919191854, 0.5523207070707079)

# %%
np.max(fedavg_prec_list[:,0]), np.max(fedavg_prec_list[:,1]), np.max(fedavg_prec_list[:,2])
# Out:
# (0.6856060606060606, 0.5350757575757566, 0.46621717171717125)

# %%
fedmach_prec_list=np.load('../save/fedmach_Eurlex_500_4_iidTrue.npy')
fedavg_prec_list=np.load('../save/fedavg_Eurlex_iidTrue.npy')
plt.figure()
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,0], 'r-', label='FedHash: Precision@1')
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,1], 'y-', label='FedHash: Precision@3')
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,2], 'b-', label='FedHash: Precision@5')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,0], 'r--', label='FedAvg: Precision@1')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,1], 'y--', label='FedAvg: Precision@3')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,2], 'b--', label='FedAvg: Precision@5')
plt.title('iid Data Partition')
plt.legend()
plt.ylabel('Precision')
plt.savefig('../save/fedmach_vs_fedavg_epc_100_B500_R4_test_acc_iid.png')

# %%
np.max(fedmach_prec_list[:,0]), np.max(fedmach_prec_list[:,1]), np.max(fedmach_prec_list[:,2])
# Out:
# (0.8142424242424242, 0.678989898989895, 0.604305555555559)

# %%
fedmach_iid_list = np.load('../save/fedmach_Eurlex_50_12_iidTrue.npy')
fedmach_noniid_list = np.load('../save/fedmach_Eurlex_50_12_iidFalse.npy')
plt.figure()
plt.plot(range(len(fedmach_iid_list)), fedmach_iid_list[:,0], 'r-', label='FedHash_iid: Precision@1')
plt.plot(range(len(fedmach_iid_list)), fedmach_iid_list[:,1], 'y-', label='FedHash_iid: Precision@3')
plt.plot(range(len(fedmach_iid_list)), fedmach_iid_list[:,2], 'b-', label='FedHash_iid: Precision@5')
plt.plot(range(len(fedmach_noniid_list)), fedmach_noniid_list[:,0], 'r--', label='FedHash_noniid: Precision@1')
plt.plot(range(len(fedmach_noniid_list)), fedmach_noniid_list[:,1], 'y--', label='FedHash_noniid: Precision@3')
plt.plot(range(len(fedmach_noniid_list)), fedmach_noniid_list[:,2], 'b--', label='FedHash_noniid: Precision@5')
plt.title('FedHash B=50')
plt.legend()
plt.ylabel('Precision')
plt.savefig('../save/fedmach_vs_fedavg_epc_100_B500_R4_test_acc_iid.png')

# %%
print(np.max(fedmach_iid_list[:,0]), np.max(fedmach_iid_list[:,1]), np.max(fedmach_iid_list[:,2]))
print(np.max(fedmach_noniid_list[:,0]), np.max(fedmach_noniid_list[:,1]), np.max(fedmach_noniid_list[:,2]))
# Out:
# 0.8187878787878788 0.6852777777777768 0.5982601010101039
# 0.7840909090909091 0.6404545454545398 0.5544747474747495

# %%
fedmach_iid_list = np.load('../save/fedmach_Eurlex_25_15_iidTrue.npy')
fedmach_noniid_list = np.load('../save/fedmach_Eurlex_25_15_iidFalse.npy')
plt.figure()
plt.plot(range(len(fedmach_iid_list)), fedmach_iid_list[:,0], 'r-', label='FedHash_iid: Precision@1')
plt.plot(range(len(fedmach_iid_list)), fedmach_iid_list[:,1], 'y-', label='FedHash_iid: Precision@3')
plt.plot(range(len(fedmach_iid_list)), fedmach_iid_list[:,2], 'b-', label='FedHash_iid: Precision@5')
plt.plot(range(len(fedmach_noniid_list)), fedmach_noniid_list[:,0], 'r--', label='FedHash_noniid: Precision@1')
plt.plot(range(len(fedmach_noniid_list)), fedmach_noniid_list[:,1], 'y--', label='FedHash_noniid: Precision@3')
plt.plot(range(len(fedmach_noniid_list)), fedmach_noniid_list[:,2], 'b--', label='FedHash_noniid: Precision@5')
plt.title('FedHash B=25')
plt.legend()
plt.ylabel('Precision')
plt.savefig('../save/fedmach_vs_fedavg_epc_100_B500_R4_test_acc_iid.png')

# %%
print(np.max(fedmach_iid_list[:,0]), np.max(fedmach_iid_list[:,1]), np.max(fedmach_iid_list[:,2]))
print(np.max(fedmach_noniid_list[:,0]), np.max(fedmach_noniid_list[:,1]), np.max(fedmach_noniid_list[:,2]))
# Out:
# 0.8228787878787879 0.6754040404040363 0.5718030303030319
# 0.7759090909090909 0.6172474747474704 0.5212853535353537

# %%
fedmach_prec_list=np.load('../save/MACH_Eurlex_iidTrue.npy')
fedavg_prec_list=np.load('../save/standard_Eurlex_iidTrue.npy')
plt.figure()
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,0], 'r-', label='MACH: Precision@1')
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,1], 'y-', label='MACH: Precision@3')
plt.plot(range(len(fedmach_prec_list)), fedmach_prec_list[:,2], 'b-', label='MACH: Precision@5')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,0], 'r--', label='Standard: Precision@1')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,1], 'y--', label='Standard: Precision@3')
plt.plot(range(len(fedavg_prec_list)), fedavg_prec_list[:,2], 'b--', label='Standard: Precision@5')
plt.title('iid Data Partition')
plt.legend(loc='lower right')
plt.ylabel('Precision')
plt.savefig('../save/fedmach_vs_fedavg_epc_100_B500_R4_test_acc_iid.png')

# %%
np.intersect1d([1, 3, 4, 3], [])
# Out:
# array([], dtype=float64)
